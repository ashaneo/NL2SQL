# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Preprocessing Functions

# %%
# !pip install fuzzywuzzy -q

# %%
import re
import pandas as pd
import nltk
import json
from nltk.tokenize import word_tokenize
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z0-9\s,.*=<>()]', '', text)
    return text

def tokenize_text(text):
    return word_tokenize(text)

def parse_schema(schema):
    tables = {}
    for table_idx, table_name in enumerate(schema['table_names']):
        columns = [schema['column_names'][idx][1] for idx in range(len(schema['column_names'])) if schema['column_names'][idx][0] == table_idx]
        tables[table_name] = {'columns': columns}
    return tables

def link_question_to_schema(question, tables):
    linked_elements = {}
    tokens = tokenize_text(question)
    for token in tokens:
        best_match = None
        highest_score = 0
        for table_name, info in tables.items():
            # Check table name match
            table_score = fuzz.partial_ratio(token.lower(), table_name.lower())
            if table_score > highest_score:
                best_match = ('table', table_name)
                highest_score = table_score
            # Check column name match
            for column in info['columns']:
                column_score = fuzz.partial_ratio(token.lower(), column.lower())
                if column_score > highest_score:
                    best_match = ('column', column)
                    highest_score = column_score
        if highest_score > 80:  # Adjust the threshold as needed
            linked_elements[token] = best_match
    return linked_elements

# %%
def preprocess_data(data, tables):
    """ Preprocess data by normalizing, tokenizing, linking to schema, and extracting features """
    processed_data = []
    questions = []
    schema_links = []
    sql_queries = []

    for entry in data:
        question = entry['question']
        normalized_question = normalize_text(question)
        tokenized_question = tokenize_text(normalized_question)
        schema_linked = link_question_to_schema(normalized_question, tables)

        processed_data.append({
            'original_question': question,
            'normalized_question': normalized_question,
            'tokenized_question': tokenized_question,
            'schema_links': schema_linked,
            'sql_query': entry['query']
        })

        questions.append(question)
        schema_links.append(schema_linked)
        sql_queries.append(entry['query'])

    return processed_data, questions, schema_links, sql_queries

# %%
def preprocess_all_data(train_data, db_schemas):
    all_processed_data = []
    questions_all = []
    schema_links_all = []
    sql_queries_all = []

    schema_mapping = {schema['db_id']: parse_schema(schema) for schema in db_schemas}

    for entry in train_data:
        db_id = entry['db_id']
        schema = schema_mapping[db_id]
        processed_entry, questions, schema_links, sql_queries = preprocess_data([entry], schema)
        all_processed_data.extend(processed_entry)

        questions_all.extend(questions)
        schema_links_all.extend(schema_links)
        sql_queries_all.extend(sql_queries)

     # Create a DataFrame from accumulated lists
    df = pd.DataFrame({
        'question': questions_all,
        'schema_links': schema_links_all,
        'sql_query': sql_queries_all
    })

    return all_processed_data, df

# %% [markdown]
# ### Loading JSON Data and Preprocessing It

# %%
import json

# %%
def load_json_file(file_path):
    """ Load a JSON file and return the data """
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# %%
db_schemas = load_json_file('/content/drive/MyDrive/ Text to Sql/spider/tables.json')
train_data = load_json_file('/content/drive/MyDrive/ Text to Sql/spider/train_spider.json')

# %%
processed_train_data, df_preprocessed_training_data_all = preprocess_all_data(train_data, db_schemas)

# %%
processed_train_data
# Out:
# [{'original_question': 'How many heads of the departments are older than 56 ?',
#   'normalized_question': 'how many heads of the departments are older than 56 ',
#   'tokenized_question': ['how',
#    'many',
#    'heads',
#    'of',
#    'the',
#    'departments',
#    'are',
#    'older',
#    'than',
#    '56'],
#   'schema_links': {'heads': ('table', 'head'),
#    'departments': ('table', 'department')},
#   'sql_query': 'SELECT count(*) FROM head WHERE age  >  56'},
#  {'original_question': 'List the name, born state and age of the heads of departments ordered by age.',
#   'normalized_question': 'list the name, born state and age of the heads of departments ordered by age.',
#   'tokenized_question': ['list',
#    'the',
#    'name',
#    ',',
#    'born',
#    'state',
#    'and',
#    'age',
#    'of',
#    'the',
#    'heads',
#    'of',
#    'departments',
#    'ordered',
#    'by',
#    'age',
#    '.'],
#   'schema_links': {'name': ('column', 'name'),
#    'born': ('column', 'born state'),
#    'state': ('column', 'born state'),
#    'age': ('column', 'age'),
#    'heads': ('table', 'head'),
#    'departments': ('table', 'department')},
#   'sql_query': 'SELECT name ,  born_state ,  age FROM head ORDER BY age'},
#  {'original_question': 'List the creation year, name and budget of each department.',
#   'normalized_question': 'list the creation year, name and budget of each department.',
#   'tokenized_question': ['list',
#    'the',
#    'creation',
#    'year',
#    ',',
#    'name',
#    'and',
#    'budget',
#    'of',
#    'each',
#    'department',
#    '.'],
#   'schema_links': {'creation': ('column', 'creation'),
#    'name': ('column', 'name'),
#    'budget': ('column', 'budget in billions'),
#    'department': ('table', 'department')},
#   'sql_query': 'SELECT creation ,  name ,  budget_in_billions FROM department'},
#  {'original_question': 'What are the maximum and minimum budget of the departments?',
#   'normalized_question': 'what are the maximum and minimum budget of the departments',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'maximum',
#    'and',
#    'minimum',
#    'budget',
#    'of',
#    'the',
#    'departments'],
#   'schema_links': {'budget': ('column', 'budget in billions'),
#    'departments': ('table', 'department')},
#   'sql_query': 'SELECT max(budget_in_billions) ,  min(budget_in_billions) FROM department'},
#  {'original_question': 'What is the average number of employees of the departments whose rank is between 10 and 15?',
#   'normalized_question': 'what is the average number of employees of the departments whose rank is between 10 and 15',
#   'tokenized_question': ['what',
#    'is',
#    'the',
#    'average',
#    'number',
#    'of',
#    'employees',
#    'of',
#    'the',
#    'departments',
#    'whose',
#    'rank',
#    'is',
#    'between',
#    '10',
#    'and',
#    '15'],
#   'schema_links': {'average': ('column', 'age'),
#    'employees': ('column', 'num employees'),
#    'departments': ('table', 'department'),
#    'rank': ('column', 'ranking')},
#   'sql_query': 'SELECT avg(num_employees) FROM department WHERE ranking BETWEEN 10 AND 15'},
#  {'original_question': 'What are the names of the heads who are born outside the California state?',
#   'normalized_question': 'what are the names of the heads who are born outside the california state',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'names',
#    'of',
#    'the',
#    'heads',
#    'who',
#    'are',
#    'born',
#    'outside',
#    'the',
#    'california',
#    'state'],
#   'schema_links': {'names': ('column', 'name'),
#    'heads': ('table', 'head'),
#    'born': ('column', 'born state'),
#    'state': ('column', 'born state')},
#   'sql_query': "SELECT name FROM head WHERE born_state != 'California'"},
#  {'original_question': "What are the distinct creation years of the departments managed by a secretary born in state 'Alabama'?",
#   'normalized_question': 'what are the distinct creation years of the departments managed by a secretary born in state alabama',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'distinct',
#    'creation',
#    'years',
#    'of',
#    'the',
#    'departments',
#    'managed',
#    'by',
#    'a',
#    'secretary',
#    'born',
#    'in',
#    'state',
#    'alabama'],
#   'schema_links': {'creation': ('column', 'creation'),
#    'departments': ('table', 'department'),
#    'managed': ('column', 'age'),
#    'a': ('table', 'department'),
#    'born': ('column', 'born state'),
#    'in': ('column', 'ranking'),
#    'state': ('column', 'born state')},
#   'sql_query': "SELECT DISTINCT T1.creation FROM department AS T1 JOIN management AS T2 ON T1.department_id  =  T2.department_id JOIN head AS T3 ON T2.head_id  =  T3.head_id WHERE T3.born_state  =  'Alabama'"},
#  {'original_question': 'What are the names of the states where at least 3 heads were born?',
#   'normalized_question': 'what are the names of the states where at least 3 heads were born',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'names',
#    'of',
#    'the',
#    'states',
#    'where',
#    'at',
#    'least',
#    '3',
#    'heads',
#    'were',
#    'born'],
#   'schema_links': {'names': ('column', 'name'),
#    'states': ('column', 'born state'),
#    'at': ('column', 'creation'),
#    'heads': ('table', 'head'),
#    'born': ('column', 'born state')},
#   'sql_query': 'SELECT born_state FROM head GROUP BY born_state HAVING count(*)  >=  3'},
#  {'original_question': 'In which year were most departments established?',
#   'normalized_question': 'in which year were most departments established',
#   'tokenized_question': ['in',
#    'which',
#    'year',
#    'were',
#    'most',
#    'departments',
#    'established'],
#   'schema_links': {'in': ('column', 'ranking'),
#    'departments': ('table', 'department'),
#    'established': ('table', 'head')},
#   'sql_query': 'SELECT creation FROM department GROUP BY creation ORDER BY count(*) DESC LIMIT 1'},
#  {'original_question': "Show the name and number of employees for the departments managed by heads whose temporary acting value is 'Yes'?",
#   'normalized_question': 'show the name and number of employees for the departments managed by heads whose temporary acting value is yes',
#   'tokenized_question': ['show',
#    'the',
#    'name',
#    'and',
#    'number',
#    'of',
#    'employees',
#    'for',
#    'the',
#    'departments',
#    'managed',
#    'by',
#    'heads',
#    'whose',
#    'temporary',
#    'acting',
#    'value',
#    'is',
#    'yes'],
#   'schema_links': {'name': ('column', 'name'),
#    'employees': ('column', 'num employees'),
#    'departments': ('table', 'department'),
#    'managed': ('column', 'age'),
#    'heads': ('table', 'head'),
#    'temporary': ('column', 'temporary acting'),
#    'acting': ('column', 'temporary acting')},
#   'sql_query': "SELECT T1.name ,  T1.num_employees FROM department AS T1 JOIN management AS T2 ON T1.department_id  =  T2.department_id WHERE T2.temporary_acting  =  'Yes'"},
#  {'original_question': 'How many acting statuses are there?',
#   'normalized_question': 'how many acting statuses are there',
#   'tokenized_question': ['how', 'many', 'acting', 'statuses', 'are', 'there'],
#   'schema_links': {'acting': ('column', 'temporary acting')},
#   'sql_query': 'SELECT count(DISTINCT temporary_acting) FROM management'},
#  {'original_question': 'How many departments are led by heads who are not mentioned?',
#   'normalized_question': 'how many departments are led by heads who are not mentioned',
#   'tokenized_question': ['how',
#    'many',
#    'departments',
#    'are',
#    'led',
#    'by',
#    'heads',
#    'who',
#    'are',
#    'not',
#    'mentioned'],
#   'schema_links': {'departments': ('table', 'department'),
#    'heads': ('table', 'head')},
#   'sql_query': 'SELECT count(*) FROM department WHERE department_id NOT IN (SELECT department_id FROM management);'},
#  {'original_question': 'What are the distinct ages of the heads who are acting?',
#   'normalized_question': 'what are the distinct ages of the heads who are acting',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'distinct',
#    'ages',
#    'of',
#    'the',
#    'heads',
#    'who',
#    'are',
#    'acting'],
#   'schema_links': {'ages': ('column', 'age'),
#    'heads': ('table', 'head'),
#    'acting': ('column', 'temporary acting')},
#   'sql_query': "SELECT DISTINCT T1.age FROM management AS T2 JOIN head AS T1 ON T1.head_id  =  T2.head_id WHERE T2.temporary_acting  =  'Yes'"},
#  {'original_question': "List the states where both the secretary of 'Treasury' department and the secretary of 'Homeland Security' were born.",
#   'normalized_question': 'list the states where both the secretary of treasury department and the secretary of homeland security were born.',
#   'tokenized_question': ['list',
#    'the',
#    'states',
#    'where',
#    'both',
#    'the',
#    'secretary',
#    'of',
#    'treasury',
#    'department',
#    'and',
#    'the',
#    'secretary',
#    'of',
#    'homeland',
#    'security',
#    'were',
#    'born',
#    '.'],
#   'schema_links': {'states': ('column', 'born state'),
#    'department': ('table', 'department'),
#    'born': ('column', 'born state')},
#   'sql_query': "SELECT T3.born_state FROM department AS T1 JOIN management AS T2 ON T1.department_id  =  T2.department_id JOIN head AS T3 ON T2.head_id  =  T3.head_id WHERE T1.name  =  'Treasury' INTERSECT SELECT T3.born_state FROM department AS T1 JOIN management AS T2 ON T1.department_id  =  T2.department_id JOIN head AS T3 ON T2.head_id  =  T3.head_id WHERE T1.name  =  'Homeland Security'"},
#  {'original_question': 'Which department has more than 1 head at a time? List the id, name and the number of heads.',
#   'normalized_question': 'which department has more than 1 head at a time list the id, name and the number of heads.',
#   'tokenized_question': ['which',
#    'department',
#    'has',
#    'more',
#    'than',
#    '1',
#    'head',
#    'at',
#    'a',
#    'time',
#    'list',
#    'the',
#    'id',
#    ',',
#    'name',
#    'and',
#    'the',
#    'number',
#    'of',
#    'heads',
#    '.'],
#   'schema_links': {'department': ('table', 'department'),
#    'head': ('table', 'head'),
#    'at': ('column', 'creation'),
#    'a': ('table', 'department'),
#    'id': ('column', 'department id'),
#    'name': ('column', 'name'),
#    'heads': ('table', 'head')},
#   'sql_query': 'SELECT T1.department_id ,  T1.name ,  count(*) FROM management AS T2 JOIN department AS T1 ON T1.department_id  =  T2.department_id GROUP BY T1.department_id HAVING count(*)  >  1'},
#  {'original_question': "Which head's name has the substring 'Ha'? List the id and name.",
#   'normalized_question': 'which heads name has the substring ha list the id and name.',
#   'tokenized_question': ['which',
#    'heads',
#    'name',
#    'has',
#    'the',
#    'substring',
#    'ha',
#    'list',
#    'the',
#    'id',
#    'and',
#    'name',
#    '.'],
#   'schema_links': {'heads': ('table', 'head'),
#    'name': ('column', 'name'),
#    'id': ('column', 'department id')},
#   'sql_query': "SELECT head_id ,  name FROM head WHERE name LIKE '%Ha%'"},
#  {'original_question': 'How many farms are there?',
#   'normalized_question': 'how many farms are there',
#   'tokenized_question': ['how', 'many', 'farms', 'are', 'there'],
#   'schema_links': {'farms': ('table', 'farm'), 'are': ('column', 'area km 2')},
#   'sql_query': 'SELECT count(*) FROM farm'},
#  {'original_question': 'Count the number of farms.',
#   'normalized_question': 'count the number of farms.',
#   'tokenized_question': ['count', 'the', 'number', 'of', 'farms', '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'of': ('column', 'official name'),
#    'farms': ('table', 'farm')},
#   'sql_query': 'SELECT count(*) FROM farm'},
#  {'original_question': 'List the total number of horses on farms in ascending order.',
#   'normalized_question': 'list the total number of horses on farms in ascending order.',
#   'tokenized_question': ['list',
#    'the',
#    'total',
#    'number',
#    'of',
#    'horses',
#    'on',
#    'farms',
#    'in',
#    'ascending',
#    'order',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'total': ('column', 'total horses'),
#    'of': ('column', 'official name'),
#    'horses': ('column', 'total horses'),
#    'on': ('column', 'population'),
#    'farms': ('table', 'farm'),
#    'in': ('column', 'census ranking')},
#   'sql_query': 'SELECT Total_Horses FROM farm ORDER BY Total_Horses ASC'},
#  {'original_question': 'What is the total horses record for each farm, sorted ascending?',
#   'normalized_question': 'what is the total horses record for each farm, sorted ascending',
#   'tokenized_question': ['what',
#    'is',
#    'the',
#    'total',
#    'horses',
#    'record',
#    'for',
#    'each',
#    'farm',
#    ',',
#    'sorted',
#    'ascending'],
#   'schema_links': {'the': ('column', 'theme'),
#    'total': ('column', 'total horses'),
#    'horses': ('column', 'total horses'),
#    'record': ('table', 'competition record'),
#    'farm': ('table', 'farm')},
#   'sql_query': 'SELECT Total_Horses FROM farm ORDER BY Total_Horses ASC'},
#  {'original_question': 'What are the hosts of competitions whose theme is not "Aliens"?',
#   'normalized_question': 'what are the hosts of competitions whose theme is not aliens',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'hosts',
#    'of',
#    'competitions',
#    'whose',
#    'theme',
#    'is',
#    'not',
#    'aliens'],
#   'schema_links': {'are': ('column', 'area km 2'),
#    'the': ('column', 'theme'),
#    'hosts': ('column', 'hosts'),
#    'of': ('column', 'official name'),
#    'competitions': ('table', 'farm competition'),
#    'theme': ('column', 'theme')},
#   'sql_query': "SELECT Hosts FROM farm_competition WHERE Theme !=  'Aliens'"},
#  {'original_question': 'Return the hosts of competitions for which the theme is not Aliens?',
#   'normalized_question': 'return the hosts of competitions for which the theme is not aliens',
#   'tokenized_question': ['return',
#    'the',
#    'hosts',
#    'of',
#    'competitions',
#    'for',
#    'which',
#    'the',
#    'theme',
#    'is',
#    'not',
#    'aliens'],
#   'schema_links': {'the': ('column', 'theme'),
#    'hosts': ('column', 'hosts'),
#    'of': ('column', 'official name'),
#    'competitions': ('table', 'farm competition'),
#    'theme': ('column', 'theme')},
#   'sql_query': "SELECT Hosts FROM farm_competition WHERE Theme !=  'Aliens'"},
#  {'original_question': 'What are the themes of farm competitions sorted by year in ascending order?',
#   'normalized_question': 'what are the themes of farm competitions sorted by year in ascending order',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'themes',
#    'of',
#    'farm',
#    'competitions',
#    'sorted',
#    'by',
#    'year',
#    'in',
#    'ascending',
#    'order'],
#   'schema_links': {'are': ('column', 'area km 2'),
#    'the': ('column', 'theme'),
#    'themes': ('column', 'theme'),
#    'of': ('column', 'official name'),
#    'farm': ('table', 'farm'),
#    'competitions': ('table', 'farm competition'),
#    'year': ('column', 'year'),
#    'in': ('column', 'census ranking')},
#   'sql_query': 'SELECT Theme FROM farm_competition ORDER BY YEAR ASC'},
#  {'original_question': 'Return the themes of farm competitions, sorted by year ascending.',
#   'normalized_question': 'return the themes of farm competitions, sorted by year ascending.',
#   'tokenized_question': ['return',
#    'the',
#    'themes',
#    'of',
#    'farm',
#    'competitions',
#    ',',
#    'sorted',
#    'by',
#    'year',
#    'ascending',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'themes': ('column', 'theme'),
#    'of': ('column', 'official name'),
#    'farm': ('table', 'farm'),
#    'competitions': ('table', 'farm competition'),
#    'year': ('column', 'year')},
#   'sql_query': 'SELECT Theme FROM farm_competition ORDER BY YEAR ASC'},
#  {'original_question': 'What is the average number of working horses of farms with more than 5000 total number of horses?',
#   'normalized_question': 'what is the average number of working horses of farms with more than 5000 total number of horses',
#   'tokenized_question': ['what',
#    'is',
#    'the',
#    'average',
#    'number',
#    'of',
#    'working',
#    'horses',
#    'of',
#    'farms',
#    'with',
#    'more',
#    'than',
#    '5000',
#    'total',
#    'number',
#    'of',
#    'horses'],
#   'schema_links': {'the': ('column', 'theme'),
#    'of': ('column', 'official name'),
#    'working': ('column', 'working horses'),
#    'horses': ('column', 'total horses'),
#    'farms': ('table', 'farm'),
#    'total': ('column', 'total horses')},
#   'sql_query': 'SELECT avg(Working_Horses) FROM farm WHERE Total_Horses  >  5000'},
#  {'original_question': 'Give the average number of working horses on farms with more than 5000 total horses.',
#   'normalized_question': 'give the average number of working horses on farms with more than 5000 total horses.',
#   'tokenized_question': ['give',
#    'the',
#    'average',
#    'number',
#    'of',
#    'working',
#    'horses',
#    'on',
#    'farms',
#    'with',
#    'more',
#    'than',
#    '5000',
#    'total',
#    'horses',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'of': ('column', 'official name'),
#    'working': ('column', 'working horses'),
#    'horses': ('column', 'total horses'),
#    'on': ('column', 'population'),
#    'farms': ('table', 'farm'),
#    'total': ('column', 'total horses')},
#   'sql_query': 'SELECT avg(Working_Horses) FROM farm WHERE Total_Horses  >  5000'},
#  {'original_question': 'What are the maximum and minimum number of cows across all farms.',
#   'normalized_question': 'what are the maximum and minimum number of cows across all farms.',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'maximum',
#    'and',
#    'minimum',
#    'number',
#    'of',
#    'cows',
#    'across',
#    'all',
#    'farms',
#    '.'],
#   'schema_links': {'are': ('column', 'area km 2'),
#    'the': ('column', 'theme'),
#    'and': ('column', 'sheep and goats'),
#    'of': ('column', 'official name'),
#    'cows': ('column', 'cows'),
#    'farms': ('table', 'farm')},
#   'sql_query': 'SELECT max(Cows) ,  min(Cows) FROM farm'},
#  {'original_question': 'Return the maximum and minimum number of cows across all farms.',
#   'normalized_question': 'return the maximum and minimum number of cows across all farms.',
#   'tokenized_question': ['return',
#    'the',
#    'maximum',
#    'and',
#    'minimum',
#    'number',
#    'of',
#    'cows',
#    'across',
#    'all',
#    'farms',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'and': ('column', 'sheep and goats'),
#    'of': ('column', 'official name'),
#    'cows': ('column', 'cows'),
#    'farms': ('table', 'farm')},
#   'sql_query': 'SELECT max(Cows) ,  min(Cows) FROM farm'},
#  {'original_question': 'How many different statuses do cities have?',
#   'normalized_question': 'how many different statuses do cities have',
#   'tokenized_question': ['how',
#    'many',
#    'different',
#    'statuses',
#    'do',
#    'cities',
#    'have'],
#   'schema_links': {'statuses': ('column', 'status')},
#   'sql_query': 'SELECT count(DISTINCT Status) FROM city'},
#  {'original_question': 'Count the number of different statuses.',
#   'normalized_question': 'count the number of different statuses.',
#   'tokenized_question': ['count',
#    'the',
#    'number',
#    'of',
#    'different',
#    'statuses',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'of': ('column', 'official name'),
#    'statuses': ('column', 'status')},
#   'sql_query': 'SELECT count(DISTINCT Status) FROM city'},
#  {'original_question': 'List official names of cities in descending order of population.',
#   'normalized_question': 'list official names of cities in descending order of population.',
#   'tokenized_question': ['list',
#    'official',
#    'names',
#    'of',
#    'cities',
#    'in',
#    'descending',
#    'order',
#    'of',
#    'population',
#    '.'],
#   'schema_links': {'official': ('column', 'official name'),
#    'names': ('column', 'official name'),
#    'of': ('column', 'official name'),
#    'in': ('column', 'census ranking'),
#    'population': ('column', 'population')},
#   'sql_query': 'SELECT Official_Name FROM city ORDER BY Population DESC'},
#  {'original_question': 'What are the official names of cities, ordered descending by population?',
#   'normalized_question': 'what are the official names of cities, ordered descending by population',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'official',
#    'names',
#    'of',
#    'cities',
#    ',',
#    'ordered',
#    'descending',
#    'by',
#    'population'],
#   'schema_links': {'are': ('column', 'area km 2'),
#    'the': ('column', 'theme'),
#    'official': ('column', 'official name'),
#    'names': ('column', 'official name'),
#    'of': ('column', 'official name'),
#    'population': ('column', 'population')},
#   'sql_query': 'SELECT Official_Name FROM city ORDER BY Population DESC'},
#  {'original_question': 'List the official name and status of the city with the largest population.',
#   'normalized_question': 'list the official name and status of the city with the largest population.',
#   'tokenized_question': ['list',
#    'the',
#    'official',
#    'name',
#    'and',
#    'status',
#    'of',
#    'the',
#    'city',
#    'with',
#    'the',
#    'largest',
#    'population',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'official': ('column', 'official name'),
#    'name': ('column', 'official name'),
#    'and': ('column', 'sheep and goats'),
#    'status': ('column', 'status'),
#    'of': ('column', 'official name'),
#    'city': ('table', 'city'),
#    'population': ('column', 'population')},
#   'sql_query': 'SELECT Official_Name ,  Status FROM city ORDER BY Population DESC LIMIT 1'},
#  {'original_question': 'What is the official name and status of the city with the most residents?',
#   'normalized_question': 'what is the official name and status of the city with the most residents',
#   'tokenized_question': ['what',
#    'is',
#    'the',
#    'official',
#    'name',
#    'and',
#    'status',
#    'of',
#    'the',
#    'city',
#    'with',
#    'the',
#    'most',
#    'residents'],
#   'schema_links': {'the': ('column', 'theme'),
#    'official': ('column', 'official name'),
#    'name': ('column', 'official name'),
#    'and': ('column', 'sheep and goats'),
#    'status': ('column', 'status'),
#    'of': ('column', 'official name'),
#    'city': ('table', 'city')},
#   'sql_query': 'SELECT Official_Name ,  Status FROM city ORDER BY Population DESC LIMIT 1'},
#  {'original_question': 'Show the years and the official names of the host cities of competitions.',
#   'normalized_question': 'show the years and the official names of the host cities of competitions.',
#   'tokenized_question': ['show',
#    'the',
#    'years',
#    'and',
#    'the',
#    'official',
#    'names',
#    'of',
#    'the',
#    'host',
#    'cities',
#    'of',
#    'competitions',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'years': ('column', 'year'),
#    'and': ('column', 'sheep and goats'),
#    'official': ('column', 'official name'),
#    'names': ('column', 'official name'),
#    'of': ('column', 'official name'),
#    'host': ('column', 'host city id'),
#    'competitions': ('table', 'farm competition')},
#   'sql_query': 'SELECT T2.Year ,  T1.Official_Name FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID'},
#  {'original_question': 'Give the years and official names of the cities of each competition.',
#   'normalized_question': 'give the years and official names of the cities of each competition.',
#   'tokenized_question': ['give',
#    'the',
#    'years',
#    'and',
#    'official',
#    'names',
#    'of',
#    'the',
#    'cities',
#    'of',
#    'each',
#    'competition',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'years': ('column', 'year'),
#    'and': ('column', 'sheep and goats'),
#    'official': ('column', 'official name'),
#    'names': ('column', 'official name'),
#    'of': ('column', 'official name'),
#    'competition': ('table', 'farm competition')},
#   'sql_query': 'SELECT T2.Year ,  T1.Official_Name FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID'},
#  {'original_question': 'Show the official names of the cities that have hosted more than one competition.',
#   'normalized_question': 'show the official names of the cities that have hosted more than one competition.',
#   'tokenized_question': ['show',
#    'the',
#    'official',
#    'names',
#    'of',
#    'the',
#    'cities',
#    'that',
#    'have',
#    'hosted',
#    'more',
#    'than',
#    'one',
#    'competition',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'official': ('column', 'official name'),
#    'names': ('column', 'official name'),
#    'of': ('column', 'official name'),
#    'competition': ('table', 'farm competition')},
#   'sql_query': 'SELECT T1.Official_Name FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID GROUP BY T2.Host_city_ID HAVING COUNT(*)  >  1'},
#  {'original_question': 'What are the official names of cities that have hosted more than one competition?',
#   'normalized_question': 'what are the official names of cities that have hosted more than one competition',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'official',
#    'names',
#    'of',
#    'cities',
#    'that',
#    'have',
#    'hosted',
#    'more',
#    'than',
#    'one',
#    'competition'],
#   'schema_links': {'are': ('column', 'area km 2'),
#    'the': ('column', 'theme'),
#    'official': ('column', 'official name'),
#    'names': ('column', 'official name'),
#    'of': ('column', 'official name'),
#    'competition': ('table', 'farm competition')},
#   'sql_query': 'SELECT T1.Official_Name FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID GROUP BY T2.Host_city_ID HAVING COUNT(*)  >  1'},
#  {'original_question': 'Show the status of the city that has hosted the greatest number of competitions.',
#   'normalized_question': 'show the status of the city that has hosted the greatest number of competitions.',
#   'tokenized_question': ['show',
#    'the',
#    'status',
#    'of',
#    'the',
#    'city',
#    'that',
#    'has',
#    'hosted',
#    'the',
#    'greatest',
#    'number',
#    'of',
#    'competitions',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'status': ('column', 'status'),
#    'of': ('column', 'official name'),
#    'city': ('table', 'city'),
#    'competitions': ('table', 'farm competition')},
#   'sql_query': 'SELECT T1.Status FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID GROUP BY T2.Host_city_ID ORDER BY COUNT(*) DESC LIMIT 1'},
#  {'original_question': 'What is the status of the city that has hosted the most competitions?',
#   'normalized_question': 'what is the status of the city that has hosted the most competitions',
#   'tokenized_question': ['what',
#    'is',
#    'the',
#    'status',
#    'of',
#    'the',
#    'city',
#    'that',
#    'has',
#    'hosted',
#    'the',
#    'most',
#    'competitions'],
#   'schema_links': {'the': ('column', 'theme'),
#    'status': ('column', 'status'),
#    'of': ('column', 'official name'),
#    'city': ('table', 'city'),
#    'competitions': ('table', 'farm competition')},
#   'sql_query': 'SELECT T1.Status FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID GROUP BY T2.Host_city_ID ORDER BY COUNT(*) DESC LIMIT 1'},
#  {'original_question': 'Please show the themes of competitions with host cities having populations larger than 1000.',
#   'normalized_question': 'please show the themes of competitions with host cities having populations larger than 1000.',
#   'tokenized_question': ['please',
#    'show',
#    'the',
#    'themes',
#    'of',
#    'competitions',
#    'with',
#    'host',
#    'cities',
#    'having',
#    'populations',
#    'larger',
#    'than',
#    '1000',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'themes': ('column', 'theme'),
#    'of': ('column', 'official name'),
#    'competitions': ('table', 'farm competition'),
#    'host': ('column', 'host city id'),
#    'populations': ('column', 'population')},
#   'sql_query': 'SELECT T2.Theme FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID WHERE T1.Population  >  1000'},
#  {'original_question': 'What are the themes of competitions that have corresponding host cities with more than 1000 residents?',
#   'normalized_question': 'what are the themes of competitions that have corresponding host cities with more than 1000 residents',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'themes',
#    'of',
#    'competitions',
#    'that',
#    'have',
#    'corresponding',
#    'host',
#    'cities',
#    'with',
#    'more',
#    'than',
#    '1000',
#    'residents'],
#   'schema_links': {'are': ('column', 'area km 2'),
#    'the': ('column', 'theme'),
#    'themes': ('column', 'theme'),
#    'of': ('column', 'official name'),
#    'competitions': ('table', 'farm competition'),
#    'host': ('column', 'host city id')},
#   'sql_query': 'SELECT T2.Theme FROM city AS T1 JOIN farm_competition AS T2 ON T1.City_ID  =  T2.Host_city_ID WHERE T1.Population  >  1000'},
#  {'original_question': 'Please show the different statuses of cities and the average population of cities with each status.',
#   'normalized_question': 'please show the different statuses of cities and the average population of cities with each status.',
#   'tokenized_question': ['please',
#    'show',
#    'the',
#    'different',
#    'statuses',
#    'of',
#    'cities',
#    'and',
#    'the',
#    'average',
#    'population',
#    'of',
#    'cities',
#    'with',
#    'each',
#    'status',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'statuses': ('column', 'status'),
#    'of': ('column', 'official name'),
#    'and': ('column', 'sheep and goats'),
#    'population': ('column', 'population'),
#    'status': ('column', 'status')},
#   'sql_query': 'SELECT Status ,  avg(Population) FROM city GROUP BY Status'},
#  {'original_question': 'What are the statuses and average populations of each city?',
#   'normalized_question': 'what are the statuses and average populations of each city',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'statuses',
#    'and',
#    'average',
#    'populations',
#    'of',
#    'each',
#    'city'],
#   'schema_links': {'are': ('column', 'area km 2'),
#    'the': ('column', 'theme'),
#    'statuses': ('column', 'status'),
#    'and': ('column', 'sheep and goats'),
#    'populations': ('column', 'population'),
#    'of': ('column', 'official name'),
#    'city': ('table', 'city')},
#   'sql_query': 'SELECT Status ,  avg(Population) FROM city GROUP BY Status'},
#  {'original_question': 'Please show the different statuses, ordered by the number of cities that have each.',
#   'normalized_question': 'please show the different statuses, ordered by the number of cities that have each.',
#   'tokenized_question': ['please',
#    'show',
#    'the',
#    'different',
#    'statuses',
#    ',',
#    'ordered',
#    'by',
#    'the',
#    'number',
#    'of',
#    'cities',
#    'that',
#    'have',
#    'each',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'statuses': ('column', 'status'),
#    'of': ('column', 'official name')},
#   'sql_query': 'SELECT Status FROM city GROUP BY Status ORDER BY COUNT(*) ASC'},
#  {'original_question': 'Return the different statuses of cities, ascending by frequency.',
#   'normalized_question': 'return the different statuses of cities, ascending by frequency.',
#   'tokenized_question': ['return',
#    'the',
#    'different',
#    'statuses',
#    'of',
#    'cities',
#    ',',
#    'ascending',
#    'by',
#    'frequency',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'statuses': ('column', 'status'),
#    'of': ('column', 'official name')},
#   'sql_query': 'SELECT Status FROM city GROUP BY Status ORDER BY COUNT(*) ASC'},
#  {'original_question': 'List the most common type of Status across cities.',
#   'normalized_question': 'list the most common type of status across cities.',
#   'tokenized_question': ['list',
#    'the',
#    'most',
#    'common',
#    'type',
#    'of',
#    'status',
#    'across',
#    'cities',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'of': ('column', 'official name'),
#    'status': ('column', 'status')},
#   'sql_query': 'SELECT Status FROM city GROUP BY Status ORDER BY COUNT(*) DESC LIMIT 1'},
#  {'original_question': 'What is the most common status across all cities?',
#   'normalized_question': 'what is the most common status across all cities',
#   'tokenized_question': ['what',
#    'is',
#    'the',
#    'most',
#    'common',
#    'status',
#    'across',
#    'all',
#    'cities'],
#   'schema_links': {'the': ('column', 'theme'), 'status': ('column', 'status')},
#   'sql_query': 'SELECT Status FROM city GROUP BY Status ORDER BY COUNT(*) DESC LIMIT 1'},
#  {'original_question': 'List the official names of cities that have not held any competition.',
#   'normalized_question': 'list the official names of cities that have not held any competition.',
#   'tokenized_question': ['list',
#    'the',
#    'official',
#    'names',
#    'of',
#    'cities',
#    'that',
#    'have',
#    'not',
#    'held',
#    'any',
#    'competition',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'official': ('column', 'official name'),
#    'names': ('column', 'official name'),
#    'of': ('column', 'official name'),
#    'competition': ('table', 'farm competition')},
#   'sql_query': 'SELECT Official_Name FROM city WHERE City_ID NOT IN (SELECT Host_city_ID FROM farm_competition)'},
#  {'original_question': 'What are the official names of cities that have not hosted a farm competition?',
#   'normalized_question': 'what are the official names of cities that have not hosted a farm competition',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'official',
#    'names',
#    'of',
#    'cities',
#    'that',
#    'have',
#    'not',
#    'hosted',
#    'a',
#    'farm',
#    'competition'],
#   'schema_links': {'are': ('column', 'area km 2'),
#    'the': ('column', 'theme'),
#    'official': ('column', 'official name'),
#    'names': ('column', 'official name'),
#    'of': ('column', 'official name'),
#    'a': ('column', 'official name'),
#    'farm': ('table', 'farm'),
#    'competition': ('table', 'farm competition')},
#   'sql_query': 'SELECT Official_Name FROM city WHERE City_ID NOT IN (SELECT Host_city_ID FROM farm_competition)'},
#  {'original_question': 'Show the status shared by cities with population bigger than 1500 and smaller than 500.',
#   'normalized_question': 'show the status shared by cities with population bigger than 1500 and smaller than 500.',
#   'tokenized_question': ['show',
#    'the',
#    'status',
#    'shared',
#    'by',
#    'cities',
#    'with',
#    'population',
#    'bigger',
#    'than',
#    '1500',
#    'and',
#    'smaller',
#    'than',
#    '500',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'status': ('column', 'status'),
#    'population': ('column', 'population'),
#    'and': ('column', 'sheep and goats')},
#   'sql_query': 'SELECT Status FROM city WHERE Population  >  1500 INTERSECT SELECT Status FROM city WHERE Population  <  500'},
#  {'original_question': 'Which statuses correspond to both cities that have a population over 1500 and cities that have a population lower than 500?',
#   'normalized_question': 'which statuses correspond to both cities that have a population over 1500 and cities that have a population lower than 500',
#   'tokenized_question': ['which',
#    'statuses',
#    'correspond',
#    'to',
#    'both',
#    'cities',
#    'that',
#    'have',
#    'a',
#    'population',
#    'over',
#    '1500',
#    'and',
#    'cities',
#    'that',
#    'have',
#    'a',
#    'population',
#    'lower',
#    'than',
#    '500'],
#   'schema_links': {'statuses': ('column', 'status'),
#    'to': ('column', 'total horses'),
#    'a': ('column', 'official name'),
#    'population': ('column', 'population'),
#    'and': ('column', 'sheep and goats')},
#   'sql_query': 'SELECT Status FROM city WHERE Population  >  1500 INTERSECT SELECT Status FROM city WHERE Population  <  500'},
#  {'original_question': 'Find the official names of cities with population bigger than 1500 or smaller than 500.',
#   'normalized_question': 'find the official names of cities with population bigger than 1500 or smaller than 500.',
#   'tokenized_question': ['find',
#    'the',
#    'official',
#    'names',
#    'of',
#    'cities',
#    'with',
#    'population',
#    'bigger',
#    'than',
#    '1500',
#    'or',
#    'smaller',
#    'than',
#    '500',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'official': ('column', 'official name'),
#    'names': ('column', 'official name'),
#    'of': ('column', 'official name'),
#    'population': ('column', 'population'),
#    'or': ('column', 'total horses')},
#   'sql_query': 'SELECT Official_Name FROM city WHERE Population  >  1500 OR Population  <  500'},
#  {'original_question': 'What are the official names of cities that have population over 1500 or less than 500?',
#   'normalized_question': 'what are the official names of cities that have population over 1500 or less than 500',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'official',
#    'names',
#    'of',
#    'cities',
#    'that',
#    'have',
#    'population',
#    'over',
#    '1500',
#    'or',
#    'less',
#    'than',
#    '500'],
#   'schema_links': {'are': ('column', 'area km 2'),
#    'the': ('column', 'theme'),
#    'official': ('column', 'official name'),
#    'names': ('column', 'official name'),
#    'of': ('column', 'official name'),
#    'population': ('column', 'population'),
#    'or': ('column', 'total horses')},
#   'sql_query': 'SELECT Official_Name FROM city WHERE Population  >  1500 OR Population  <  500'},
#  {'original_question': 'Show the census ranking of cities whose status are not "Village".',
#   'normalized_question': 'show the census ranking of cities whose status are not village.',
#   'tokenized_question': ['show',
#    'the',
#    'census',
#    'ranking',
#    'of',
#    'cities',
#    'whose',
#    'status',
#    'are',
#    'not',
#    'village',
#    '.'],
#   'schema_links': {'the': ('column', 'theme'),
#    'census': ('column', 'census ranking'),
#    'ranking': ('column', 'census ranking'),
#    'of': ('column', 'official name'),
#    'status': ('column', 'status'),
#    'are': ('column', 'area km 2')},
#   'sql_query': 'SELECT Census_Ranking FROM city WHERE Status !=  "Village"'},
#  {'original_question': 'What are the census rankings of cities that do not have the status "Village"?',
#   'normalized_question': 'what are the census rankings of cities that do not have the status village',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'census',
#    'rankings',
#    'of',
#    'cities',
#    'that',
#    'do',
#    'not',
#    'have',
#    'the',
#    'status',
#    'village'],
#   'schema_links': {'are': ('column', 'area km 2'),
#    'the': ('column', 'theme'),
#    'census': ('column', 'census ranking'),
#    'rankings': ('column', 'rank'),
#    'of': ('column', 'official name'),
#    'status': ('column', 'status')},
#   'sql_query': 'SELECT Census_Ranking FROM city WHERE Status !=  "Village"'},
#  {'original_question': 'which course has most number of registered students?',
#   'normalized_question': 'which course has most number of registered students',
#   'tokenized_question': ['which',
#    'course',
#    'has',
#    'most',
#    'number',
#    'of',
#    'registered',
#    'students'],
#   'schema_links': {'course': ('table', 'courses'),
#    'number': ('column', 'cell mobile number'),
#    'of': ('column', 'date of attendance'),
#    'students': ('table', 'students')},
#   'sql_query': 'SELECT T1.course_name FROM courses AS T1 JOIN student_course_registrations AS T2 ON T1.course_id = T2.course_Id GROUP BY T1.course_id ORDER BY count(*) DESC LIMIT 1'},
#  {'original_question': 'What is the name of the course with the most registered students?',
#   'normalized_question': 'what is the name of the course with the most registered students',
#   'tokenized_question': ['what',
#    'is',
#    'the',
#    'name',
#    'of',
#    'the',
#    'course',
#    'with',
#    'the',
#    'most',
#    'registered',
#    'students'],
#   'schema_links': {'is': ('table', 'student course registrations'),
#    'the': ('column', 'other details'),
#    'name': ('column', 'first name'),
#    'of': ('column', 'date of attendance'),
#    'course': ('table', 'courses'),
#    'students': ('table', 'students')},
#   'sql_query': 'SELECT T1.course_name FROM courses AS T1 JOIN student_course_registrations AS T2 ON T1.course_id = T2.course_Id GROUP BY T1.course_id ORDER BY count(*) DESC LIMIT 1'},
#  {'original_question': 'what is id of students who registered some courses but the least number of courses in these students?',
#   'normalized_question': 'what is id of students who registered some courses but the least number of courses in these students',
#   'tokenized_question': ['what',
#    'is',
#    'id',
#    'of',
#    'students',
#    'who',
#    'registered',
#    'some',
#    'courses',
#    'but',
#    'the',
#    'least',
#    'number',
#    'of',
#    'courses',
#    'in',
#    'these',
#    'students'],
#   'schema_links': {'is': ('table', 'student course registrations'),
#    'id': ('column', 'address id'),
#    'of': ('column', 'date of attendance'),
#    'students': ('table', 'students'),
#    'courses': ('table', 'courses'),
#    'the': ('column', 'other details'),
#    'number': ('column', 'cell mobile number'),
#    'in': ('column', 'line 1')},
#   'sql_query': 'SELECT student_id FROM student_course_registrations GROUP BY student_id ORDER BY count(*) LIMIT 1'},
#  {'original_question': 'What are the ids of the students who registered for some courses but had the least number of courses for all students?',
#   'normalized_question': 'what are the ids of the students who registered for some courses but had the least number of courses for all students',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'ids',
#    'of',
#    'the',
#    'students',
#    'who',
#    'registered',
#    'for',
#    'some',
#    'courses',
#    'but',
#    'had',
#    'the',
#    'least',
#    'number',
#    'of',
#    'courses',
#    'for',
#    'all',
#    'students'],
#   'schema_links': {'the': ('column', 'other details'),
#    'of': ('column', 'date of attendance'),
#    'students': ('table', 'students'),
#    'courses': ('table', 'courses'),
#    'number': ('column', 'cell mobile number')},
#   'sql_query': 'SELECT student_id FROM student_course_registrations GROUP BY student_id ORDER BY count(*) LIMIT 1'},
#  {'original_question': 'what are the first name and last name of all candidates?',
#   'normalized_question': 'what are the first name and last name of all candidates',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'first',
#    'name',
#    'and',
#    'last',
#    'name',
#    'of',
#    'all',
#    'candidates'],
#   'schema_links': {'the': ('column', 'other details'),
#    'first': ('column', 'first name'),
#    'name': ('column', 'first name'),
#    'and': ('table', 'candidates'),
#    'last': ('column', 'last name'),
#    'of': ('column', 'date of attendance'),
#    'candidates': ('table', 'candidates')},
#   'sql_query': 'SELECT T2.first_name ,  T2.last_name FROM candidates AS T1 JOIN people AS T2 ON T1.candidate_id = T2.person_id'},
#  {'original_question': 'What are the first and last names of all the candidates?',
#   'normalized_question': 'what are the first and last names of all the candidates',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'first',
#    'and',
#    'last',
#    'names',
#    'of',
#    'all',
#    'the',
#    'candidates'],
#   'schema_links': {'the': ('column', 'other details'),
#    'first': ('column', 'first name'),
#    'and': ('table', 'candidates'),
#    'last': ('column', 'last name'),
#    'names': ('column', 'first name'),
#    'of': ('column', 'date of attendance'),
#    'candidates': ('table', 'candidates')},
#   'sql_query': 'SELECT T2.first_name ,  T2.last_name FROM candidates AS T1 JOIN people AS T2 ON T1.candidate_id = T2.person_id'},
#  {'original_question': 'List the id of students who never attends courses?',
#   'normalized_question': 'list the id of students who never attends courses',
#   'tokenized_question': ['list',
#    'the',
#    'id',
#    'of',
#    'students',
#    'who',
#    'never',
#    'attends',
#    'courses'],
#   'schema_links': {'the': ('column', 'other details'),
#    'id': ('column', 'address id'),
#    'of': ('column', 'date of attendance'),
#    'students': ('table', 'students'),
#    'attends': ('table', 'student course attendance'),
#    'courses': ('table', 'courses')},
#   'sql_query': 'SELECT student_id FROM students WHERE student_id NOT IN (SELECT student_id FROM student_course_attendance)'},
#  {'original_question': 'What are the  ids of every student who has never attended a course?',
#   'normalized_question': 'what are the  ids of every student who has never attended a course',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'ids',
#    'of',
#    'every',
#    'student',
#    'who',
#    'has',
#    'never',
#    'attended',
#    'a',
#    'course'],
#   'schema_links': {'the': ('column', 'other details'),
#    'of': ('column', 'date of attendance'),
#    'student': ('table', 'students'),
#    'a': ('table', 'addresses'),
#    'course': ('table', 'courses')},
#   'sql_query': 'SELECT student_id FROM students WHERE student_id NOT IN (SELECT student_id FROM student_course_attendance)'},
#  {'original_question': 'List the id of students who attended some courses?',
#   'normalized_question': 'list the id of students who attended some courses',
#   'tokenized_question': ['list',
#    'the',
#    'id',
#    'of',
#    'students',
#    'who',
#    'attended',
#    'some',
#    'courses'],
#   'schema_links': {'the': ('column', 'other details'),
#    'id': ('column', 'address id'),
#    'of': ('column', 'date of attendance'),
#    'students': ('table', 'students'),
#    'courses': ('table', 'courses')},
#   'sql_query': 'SELECT student_id FROM student_course_attendance'},
#  {'original_question': 'What are the ids of all students who have attended at least one course?',
#   'normalized_question': 'what are the ids of all students who have attended at least one course',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'ids',
#    'of',
#    'all',
#    'students',
#    'who',
#    'have',
#    'attended',
#    'at',
#    'least',
#    'one',
#    'course'],
#   'schema_links': {'the': ('column', 'other details'),
#    'of': ('column', 'date of attendance'),
#    'students': ('table', 'students'),
#    'at': ('column', 'state province county'),
#    'course': ('table', 'courses')},
#   'sql_query': 'SELECT student_id FROM student_course_attendance'},
#  {'original_question': 'What are the ids of all students for courses and what are the names of those courses?',
#   'normalized_question': 'what are the ids of all students for courses and what are the names of those courses',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'ids',
#    'of',
#    'all',
#    'students',
#    'for',
#    'courses',
#    'and',
#    'what',
#    'are',
#    'the',
#    'names',
#    'of',
#    'those',
#    'courses'],
#   'schema_links': {'the': ('column', 'other details'),
#    'of': ('column', 'date of attendance'),
#    'students': ('table', 'students'),
#    'courses': ('table', 'courses'),
#    'and': ('table', 'candidates'),
#    'names': ('column', 'first name')},
#   'sql_query': 'SELECT T1.student_id ,  T2.course_name FROM student_course_registrations AS T1 JOIN courses AS T2 ON T1.course_id = T2.course_id'},
#  {'original_question': 'What is detail of the student who most recently registered course?',
#   'normalized_question': 'what is detail of the student who most recently registered course',
#   'tokenized_question': ['what',
#    'is',
#    'detail',
#    'of',
#    'the',
#    'student',
#    'who',
#    'most',
#    'recently',
#    'registered',
#    'course'],
#   'schema_links': {'is': ('table', 'student course registrations'),
#    'detail': ('column', 'student details'),
#    'of': ('column', 'date of attendance'),
#    'the': ('column', 'other details'),
#    'student': ('table', 'students'),
#    'course': ('table', 'courses')},
#   'sql_query': 'SELECT T2.student_details FROM student_course_registrations AS T1 JOIN students AS T2 ON T1.student_id = T2.student_id ORDER BY T1.registration_date DESC LIMIT 1'},
#  {'original_question': 'What details do we have on the students who registered for courses most recently?',
#   'normalized_question': 'what details do we have on the students who registered for courses most recently',
#   'tokenized_question': ['what',
#    'details',
#    'do',
#    'we',
#    'have',
#    'on',
#    'the',
#    'students',
#    'who',
#    'registered',
#    'for',
#    'courses',
#    'most',
#    'recently'],
#   'schema_links': {'details': ('column', 'student details'),
#    'on': ('column', 'person id'),
#    'the': ('column', 'other details'),
#    'students': ('table', 'students'),
#    'courses': ('table', 'courses')},
#   'sql_query': 'SELECT T2.student_details FROM student_course_registrations AS T1 JOIN students AS T2 ON T1.student_id = T2.student_id ORDER BY T1.registration_date DESC LIMIT 1'},
#  {'original_question': 'How many students attend course English?',
#   'normalized_question': 'how many students attend course english',
#   'tokenized_question': ['how',
#    'many',
#    'students',
#    'attend',
#    'course',
#    'english'],
# ...
#   'sql_query': 'SELECT name FROM enzyme WHERE name LIKE "%ALA%"'},
#  {'original_question': 'find the number of medicines offered by each trade.',
#   'normalized_question': 'find the number of medicines offered by each trade.',
#   'tokenized_question': ['find',
#    'the',
#    'number',
#    'of',
#    'medicines',
#    'offered',
#    'by',
#    'each',
#    'trade',
#    '.'],
#   'schema_links': {'medicines': ('table', 'medicine'),
#    'trade': ('column', 'trade name')},
#   'sql_query': 'SELECT trade_name ,  count(*) FROM medicine GROUP BY trade_name'},
#  {'original_question': 'How many medicines are offered by each trade name?',
#   'normalized_question': 'how many medicines are offered by each trade name',
#   'tokenized_question': ['how',
#    'many',
#    'medicines',
#    'are',
#    'offered',
#    'by',
#    'each',
#    'trade',
#    'name'],
#   'schema_links': {'medicines': ('table', 'medicine'),
#    'trade': ('column', 'trade name'),
#    'name': ('column', 'name')},
#   'sql_query': 'SELECT trade_name ,  count(*) FROM medicine GROUP BY trade_name'},
#  {'original_question': 'List all schools and their nicknames in the order of founded year.',
#   'normalized_question': 'list all schools and their nicknames in the order of founded year.',
#   'tokenized_question': ['list',
#    'all',
#    'schools',
#    'and',
#    'their',
#    'nicknames',
#    'in',
#    'the',
#    'order',
#    'of',
#    'founded',
#    'year',
#    '.'],
#   'schema_links': {'all': ('table', 'basketball match'),
#    'schools': ('column', 'school'),
#    'nicknames': ('column', 'nickname'),
#    'founded': ('column', 'founded')},
#   'sql_query': 'SELECT school ,  nickname FROM university ORDER BY founded'},
#  {'original_question': 'What are the different schools and their nicknames, ordered by their founding years?',
#   'normalized_question': 'what are the different schools and their nicknames, ordered by their founding years',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'different',
#    'schools',
#    'and',
#    'their',
#    'nicknames',
#    ',',
#    'ordered',
#    'by',
#    'their',
#    'founding',
#    'years'],
#   'schema_links': {'schools': ('column', 'school'),
#    'nicknames': ('column', 'nickname')},
#   'sql_query': 'SELECT school ,  nickname FROM university ORDER BY founded'},
#  {'original_question': 'List all public schools and their locations.',
#   'normalized_question': 'list all public schools and their locations.',
#   'tokenized_question': ['list',
#    'all',
#    'public',
#    'schools',
#    'and',
#    'their',
#    'locations',
#    '.'],
#   'schema_links': {'all': ('table', 'basketball match'),
#    'schools': ('column', 'school'),
#    'locations': ('column', 'location')},
#   'sql_query': "SELECT school ,  LOCATION FROM university WHERE affiliation  =  'Public'"},
#  {'original_question': 'What are the public schools and what are their locations?',
#   'normalized_question': 'what are the public schools and what are their locations',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'public',
#    'schools',
#    'and',
#    'what',
#    'are',
#    'their',
#    'locations'],
#   'schema_links': {'schools': ('column', 'school'),
#    'locations': ('column', 'location')},
#   'sql_query': "SELECT school ,  LOCATION FROM university WHERE affiliation  =  'Public'"},
#  {'original_question': 'When was the school with the largest enrollment founded?',
#   'normalized_question': 'when was the school with the largest enrollment founded',
#   'tokenized_question': ['when',
#    'was',
#    'the',
#    'school',
#    'with',
#    'the',
#    'largest',
#    'enrollment',
#    'founded'],
#   'schema_links': {'school': ('column', 'school id'),
#    'enrollment': ('column', 'enrollment'),
#    'founded': ('column', 'founded')},
#   'sql_query': 'SELECT founded FROM university ORDER BY enrollment DESC LIMIT 1'},
#  {'original_question': 'Return the founded year for the school with the largest enrollment.',
#   'normalized_question': 'return the founded year for the school with the largest enrollment.',
#   'tokenized_question': ['return',
#    'the',
#    'founded',
#    'year',
#    'for',
#    'the',
#    'school',
#    'with',
#    'the',
#    'largest',
#    'enrollment',
#    '.'],
#   'schema_links': {'founded': ('column', 'founded'),
#    'school': ('column', 'school id'),
#    'enrollment': ('column', 'enrollment')},
#   'sql_query': 'SELECT founded FROM university ORDER BY enrollment DESC LIMIT 1'},
#  {'original_question': 'Find the founded year of the newest non public school.',
#   'normalized_question': 'find the founded year of the newest non public school.',
#   'tokenized_question': ['find',
#    'the',
#    'founded',
#    'year',
#    'of',
#    'the',
#    'newest',
#    'non',
#    'public',
#    'school',
#    '.'],
#   'schema_links': {'founded': ('column', 'founded'),
#    'school': ('column', 'school id')},
#   'sql_query': "SELECT founded FROM university WHERE affiliation != 'Public' ORDER BY founded DESC LIMIT 1"},
#  {'original_question': 'What is the founded year of the non public school that was founded most recently?',
#   'normalized_question': 'what is the founded year of the non public school that was founded most recently',
#   'tokenized_question': ['what',
#    'is',
#    'the',
#    'founded',
#    'year',
#    'of',
#    'the',
#    'non',
#    'public',
#    'school',
#    'that',
#    'was',
#    'founded',
#    'most',
#    'recently'],
#   'schema_links': {'founded': ('column', 'founded'),
#    'school': ('column', 'school id')},
#   'sql_query': "SELECT founded FROM university WHERE affiliation != 'Public' ORDER BY founded DESC LIMIT 1"},
#  {'original_question': 'How many schools are in the basketball match?',
#   'normalized_question': 'how many schools are in the basketball match',
#   'tokenized_question': ['how',
#    'many',
#    'schools',
#    'are',
#    'in',
#    'the',
#    'basketball',
#    'match'],
#   'schema_links': {'schools': ('column', 'school'),
#    'basketball': ('table', 'basketball match'),
#    'match': ('table', 'basketball match')},
#   'sql_query': 'SELECT count(DISTINCT school_id) FROM basketball_match'},
#  {'original_question': 'Count the number of schools that have had basketball matches.',
#   'normalized_question': 'count the number of schools that have had basketball matches.',
#   'tokenized_question': ['count',
#    'the',
#    'number',
#    'of',
#    'schools',
#    'that',
#    'have',
#    'had',
#    'basketball',
#    'matches',
#    '.'],
#   'schema_links': {'schools': ('column', 'school'),
#    'basketball': ('table', 'basketball match'),
#    'matches': ('table', 'basketball match')},
#   'sql_query': 'SELECT count(DISTINCT school_id) FROM basketball_match'},
#  {'original_question': 'What is the highest acc percent score in the competition?',
#   'normalized_question': 'what is the highest acc percent score in the competition',
#   'tokenized_question': ['what',
#    'is',
#    'the',
#    'highest',
#    'acc',
#    'percent',
#    'score',
#    'in',
#    'the',
#    'competition'],
#   'schema_links': {'acc': ('column', 'acc regular season'),
#    'percent': ('column', 'acc percent')},
#   'sql_query': 'SELECT acc_percent FROM basketball_match ORDER BY acc_percent DESC LIMIT 1'},
#  {'original_question': 'Return the highest acc percent across all basketball matches.',
#   'normalized_question': 'return the highest acc percent across all basketball matches.',
#   'tokenized_question': ['return',
#    'the',
#    'highest',
#    'acc',
#    'percent',
#    'across',
#    'all',
#    'basketball',
#    'matches',
#    '.'],
#   'schema_links': {'acc': ('column', 'acc regular season'),
#    'percent': ('column', 'acc percent'),
#    'all': ('table', 'basketball match'),
#    'basketball': ('table', 'basketball match'),
#    'matches': ('table', 'basketball match')},
#   'sql_query': 'SELECT acc_percent FROM basketball_match ORDER BY acc_percent DESC LIMIT 1'},
#  {'original_question': 'What is the primary conference of the school that has the lowest acc percent score in the competition?',
#   'normalized_question': 'what is the primary conference of the school that has the lowest acc percent score in the competition',
#   'tokenized_question': ['what',
#    'is',
#    'the',
#    'primary',
#    'conference',
#    'of',
#    'the',
#    'school',
#    'that',
#    'has',
#    'the',
#    'lowest',
#    'acc',
#    'percent',
#    'score',
#    'in',
#    'the',
#    'competition'],
#   'schema_links': {'primary': ('column', 'primary conference'),
#    'conference': ('column', 'primary conference'),
#    'school': ('column', 'school id'),
#    'acc': ('column', 'acc regular season'),
#    'percent': ('column', 'acc percent')},
#   'sql_query': 'SELECT t1.Primary_conference FROM university AS t1 JOIN basketball_match AS t2 ON t1.school_id  =  t2.school_id ORDER BY t2.acc_percent LIMIT 1'},
#  {'original_question': 'Return the primary conference of the school with the lowest acc percentage score.',
#   'normalized_question': 'return the primary conference of the school with the lowest acc percentage score.',
#   'tokenized_question': ['return',
#    'the',
#    'primary',
#    'conference',
#    'of',
#    'the',
#    'school',
#    'with',
#    'the',
#    'lowest',
#    'acc',
#    'percentage',
#    'score',
#    '.'],
#   'schema_links': {'primary': ('column', 'primary conference'),
#    'conference': ('column', 'primary conference'),
#    'school': ('column', 'school id'),
#    'acc': ('column', 'acc regular season'),
#    'percentage': ('column', 'acc percent')},
#   'sql_query': 'SELECT t1.Primary_conference FROM university AS t1 JOIN basketball_match AS t2 ON t1.school_id  =  t2.school_id ORDER BY t2.acc_percent LIMIT 1'},
#  {'original_question': 'What is the team name and acc regular season score of the school that was founded for the longest time?',
#   'normalized_question': 'what is the team name and acc regular season score of the school that was founded for the longest time',
#   'tokenized_question': ['what',
#    'is',
#    'the',
#    'team',
#    'name',
#    'and',
#    'acc',
#    'regular',
#    'season',
#    'score',
#    'of',
#    'the',
#    'school',
#    'that',
#    'was',
#    'founded',
#    'for',
#    'the',
#    'longest',
#    'time'],
#   'schema_links': {'team': ('column', 'team id'),
#    'name': ('column', 'team name'),
#    'acc': ('column', 'acc regular season'),
#    'regular': ('column', 'acc regular season'),
#    'season': ('column', 'acc regular season'),
#    'school': ('column', 'school id'),
#    'founded': ('column', 'founded')},
#   'sql_query': 'SELECT t2.team_name ,  t2.ACC_Regular_Season FROM university AS t1 JOIN basketball_match AS t2 ON t1.school_id  =  t2.school_id ORDER BY t1.founded LIMIT 1'},
#  {'original_question': 'Return the name of the team and the acc during the regular season for the school that was founded the earliest.',
#   'normalized_question': 'return the name of the team and the acc during the regular season for the school that was founded the earliest.',
#   'tokenized_question': ['return',
#    'the',
#    'name',
#    'of',
#    'the',
#    'team',
#    'and',
#    'the',
#    'acc',
#    'during',
#    'the',
#    'regular',
#    'season',
#    'for',
#    'the',
#    'school',
#    'that',
#    'was',
#    'founded',
#    'the',
#    'earliest',
#    '.'],
#   'schema_links': {'name': ('column', 'team name'),
#    'team': ('column', 'team id'),
#    'acc': ('column', 'acc regular season'),
#    'regular': ('column', 'acc regular season'),
#    'season': ('column', 'acc regular season'),
#    'school': ('column', 'school id'),
#    'founded': ('column', 'founded')},
#   'sql_query': 'SELECT t2.team_name ,  t2.ACC_Regular_Season FROM university AS t1 JOIN basketball_match AS t2 ON t1.school_id  =  t2.school_id ORDER BY t1.founded LIMIT 1'},
#  {'original_question': 'Find the location and all games score of the school that has Clemson as its team name.',
#   'normalized_question': 'find the location and all games score of the school that has clemson as its team name.',
#   'tokenized_question': ['find',
#    'the',
#    'location',
#    'and',
#    'all',
#    'games',
#    'score',
#    'of',
#    'the',
#    'school',
#    'that',
#    'has',
#    'clemson',
#    'as',
#    'its',
#    'team',
#    'name',
#    '.'],
#   'schema_links': {'location': ('column', 'location'),
#    'all': ('table', 'basketball match'),
#    'games': ('column', 'all games'),
#    'school': ('column', 'school id'),
#    'as': ('table', 'basketball match'),
#    'team': ('column', 'team id'),
#    'name': ('column', 'team name')},
#   'sql_query': "SELECT t2.All_Games ,  t1.location FROM university AS t1 JOIN basketball_match AS t2 ON t1.school_id  =  t2.school_id WHERE team_name  =  'Clemson'"},
#  {'original_question': 'What are the all games score and location of the school called Clemson?',
#   'normalized_question': 'what are the all games score and location of the school called clemson',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'all',
#    'games',
#    'score',
#    'and',
#    'location',
#    'of',
#    'the',
#    'school',
#    'called',
#    'clemson'],
#   'schema_links': {'all': ('table', 'basketball match'),
#    'games': ('column', 'all games'),
#    'location': ('column', 'location'),
#    'school': ('column', 'school id')},
#   'sql_query': "SELECT t2.All_Games ,  t1.location FROM university AS t1 JOIN basketball_match AS t2 ON t1.school_id  =  t2.school_id WHERE team_name  =  'Clemson'"},
#  {'original_question': 'What are the average enrollment size of the universities that are founded before 1850?',
#   'normalized_question': 'what are the average enrollment size of the universities that are founded before 1850',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'average',
#    'enrollment',
#    'size',
#    'of',
#    'the',
#    'universities',
#    'that',
#    'are',
#    'founded',
#    'before',
#    '1850'],
#   'schema_links': {'enrollment': ('column', 'enrollment'),
#    'universities': ('table', 'university'),
#    'founded': ('column', 'founded')},
#   'sql_query': 'SELECT avg(enrollment) FROM university WHERE founded  <  1850'},
#  {'original_question': 'Return the average enrollment of universities founded before 1850.',
#   'normalized_question': 'return the average enrollment of universities founded before 1850.',
#   'tokenized_question': ['return',
#    'the',
#    'average',
#    'enrollment',
#    'of',
#    'universities',
#    'founded',
#    'before',
#    '1850',
#    '.'],
#   'schema_links': {'enrollment': ('column', 'enrollment'),
#    'universities': ('table', 'university'),
#    'founded': ('column', 'founded')},
#   'sql_query': 'SELECT avg(enrollment) FROM university WHERE founded  <  1850'},
#  {'original_question': 'Show the enrollment and primary_conference of the oldest college.',
#   'normalized_question': 'show the enrollment and primaryconference of the oldest college.',
#   'tokenized_question': ['show',
#    'the',
#    'enrollment',
#    'and',
#    'primaryconference',
#    'of',
#    'the',
#    'oldest',
#    'college',
#    '.'],
#   'schema_links': {'enrollment': ('column', 'enrollment'),
#    'primaryconference': ('column', 'primary conference')},
#   'sql_query': 'SELECT enrollment ,  primary_conference FROM university ORDER BY founded LIMIT 1'},
#  {'original_question': 'What are the enrollment and primary conference for the university which was founded the earliest?',
#   'normalized_question': 'what are the enrollment and primary conference for the university which was founded the earliest',
#   'tokenized_question': ['what',
#    'are',
#    'the',
#    'enrollment',
#    'and',
#    'primary',
#    'conference',
#    'for',
#    'the',
#    'university',
#    'which',
#    'was',
#    'founded',
#    'the',
#    'earliest'],
#   'schema_links': {'enrollment': ('column', 'enrollment'),
#    'primary': ('column', 'primary conference'),
#    'conference': ('column', 'primary conference'),
#    'university': ('table', 'university'),
#    'founded': ('column', 'founded')},
#   'sql_query': 'SELECT enrollment ,  primary_conference FROM university ORDER BY founded LIMIT 1'},
#  {'original_question': 'What is the total and minimum enrollment of all schools?',
#   'normalized_question': 'what is the total and minimum enrollment of all schools',
#   'tokenized_question': ['what',
#    'is',
#    'the',
#    'total',
#    'and',
#    'minimum',
#    'enrollment',
#    'of',
#    'all',
#    'schools'],
#   'schema_links': {'enrollment': ('column', 'enrollment'),
#    'all': ('table', 'basketball match'),
#    'schools': ('column', 'school')},
#   'sql_query': 'SELECT sum(enrollment) ,  min(enrollment) FROM university'},
#  ...]

# %%
df_preprocessed_training_data_all
# Out:
#                                                question  \
# 0     How many heads of the departments are older th...
# 1     List the name, born state and age of the heads...
# 2     List the creation year, name and budget of eac...
# 3     What are the maximum and minimum budget of the...
# 4     What is the average number of employees of the...
# ...                                                 ...
# 6995  What are all the company names that have a boo...
# 6996  Show the movie titles and book titles for all ...
# 6997  What are the titles of movies and books corres...
# 6998  Show all company names with a movie directed i...
# 6999  What are all company names that have a corresp...
#
#                                            schema_links  \
# 0     {'heads': ('table', 'head'), 'departments': ('...
# 1     {'name': ('column', 'name'), 'born': ('column'...
# 2     {'creation': ('column', 'creation'), 'name': (...
# 3     {'budget': ('column', 'budget in billions'), '...
# 4     {'average': ('column', 'age'), 'employees': ('...
# ...                                                 ...
# 6995  {'are': ('column', 'group equity shareholding'...
# 6996  {'movie': ('table', 'movie'), 'titles': ('colu...
# 6997  {'are': ('column', 'group equity shareholding'...
# 6998  {'company': ('table', 'culture company'), 'nam...
# 6999  {'are': ('column', 'group equity shareholding'...
#
#                                               sql_query
# 0            SELECT count(*) FROM head WHERE age  >  56
# 1     SELECT name ,  born_state ,  age FROM head ORD...
# 2     SELECT creation ,  name ,  budget_in_billions ...
# 3     SELECT max(budget_in_billions) ,  min(budget_i...
# 4     SELECT avg(num_employees) FROM department WHER...
# ...                                                 ...
# 6995  SELECT T1.company_name FROM culture_company AS...
# 6996  SELECT T1.title ,  T3.book_title FROM movie AS...
# 6997  SELECT T1.title ,  T3.book_title FROM movie AS...
# 6998  SELECT T2.company_name FROM movie AS T1 JOIN c...
# 6999  SELECT T2.company_name FROM movie AS T1 JOIN c...
#
# [7000 rows x 3 columns]

# %% [markdown]
# ### Model Architecture

# %%
from transformers import BertModel, BertTokenizer
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

# %%
class TextToSQLModel(nn.Module):
    def __init__(self, tokenizer_vocab_size):
        super(TextToSQLModel, self).__init__()
        self.encoder = BertModel.from_pretrained('bert-base-uncased')
        self.decoder = nn.TransformerDecoder(
            nn.TransformerDecoderLayer(d_model=768, nhead=8), num_layers=6
        )
        self.embedding = nn.Embedding(tokenizer_vocab_size, 768)
        self.output_linear = nn.Linear(768, tokenizer_vocab_size)

    def forward(self, input_ids, attention_mask, tgt_tokens):
        encoder_hidden_states = self.encoder(input_ids=input_ids, attention_mask=attention_mask)[0]
        tgt_embeddings = self.embedding(tgt_tokens)  # Embedding target tokens
        decoder_outputs = self.decoder(tgt_embeddings, encoder_hidden_states)
        output = self.output_linear(decoder_outputs)
        return output

# %%
class SQLDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=512):
        self.data = data
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        inputs = self.tokenizer.encode_plus(
            item['normalized_question'],
            None,
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            return_attention_mask=True,
            truncation=True
        )
        targets = self.tokenizer.encode(
            item['sql_query'],
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            truncation=True
        )
        return {
            'input_ids': torch.tensor(inputs['input_ids']),
            'attention_mask': torch.tensor(inputs['attention_mask']),
            'labels': torch.tensor(targets)
        }

# %%
from tqdm import tqdm

def train_model(model, data_loader, optimizer, device, epochs=3):
  model.train()
  total_loss = 0
  for epoch in range(epochs):
        total_loss = 0
        progress_bar = tqdm(data_loader, desc=f'Epoch {epoch+1}/{epochs}', leave=False)
        for batch in progress_bar:
            optimizer.zero_grad()
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask, labels)
            loss = nn.CrossEntropyLoss()(outputs.transpose(1, 2), labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            progress_bar.set_postfix({'Batch Loss': loss.item()})

        avg_loss = total_loss / len(data_loader)
        total_loss += avg_loss
        print (f'End of Epoch {epoch+1}, Average Loss: {avg_loss:.4f}')
  return f"total loss : {total_loss} , total average loss ={total_loss/epochs}"

# %%
def evaluate_model(model, data_loader, device):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask, labels)
            loss = nn.CrossEntropyLoss()(outputs.transpose(1, 2), labels)
            total_loss += loss.item()
    return total_loss / len(data_loader)

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Obtain the vocabulary size from the tokenizer
tokenizer_vocab_size = tokenizer.vocab_size

# Initialize the model with the required vocabulary size
model = TextToSQLModel(tokenizer_vocab_size).to(device)

# Set up the optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=5e-5)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()

# %%
train_dataset = SQLDataset(processed_train_data, tokenizer)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)

# %%
# Call training
train_loss = train_model(model, train_loader, optimizer, device)
# Out:
# End of Epoch 1, Average Loss: 0.1399
# End of Epoch 2, Average Loss: 0.0190
# End of Epoch 3, Average Loss: 0.0080

# %%
print("Training loss:", train_loss)
# Out:
# Training loss: total loss : 6.980382935216917 , total average loss =2.3267943117389724

# %% [markdown]
# ### Save the Model

# %%
def save_model(model, optimizer, file_path):
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, file_path)

# Example usage:
save_path = '/content/drive/MyDrive/text_to_sql_model_full_trained.pth'
save_model(model, optimizer, save_path)

# %% [markdown]
# ### Using the Model

# %%
# Mock-up of schema parsing (assuming it's already defined)
schema = {
    'table_names': ['products', 'categories'],
    'column_names': [
        (0, 'product_id'), (0, 'name'), (0, 'price'), (0, 'category_id'),
        (1, 'category_id'), (1, 'category_name')
    ]
}

def parse_schema(schema):
    """ Parse the database schema into a dictionary mapping table names to their columns. """
    tables = {}
    for table_idx, table_name in enumerate(schema['table_names']):
        columns = [schema['column_names'][idx][1] for idx in range(len(schema['column_names'])) if schema['column_names'][idx][0] == table_idx]
        tables[table_name] = {'columns': columns}
    return tables

# Preprocess the input text
def preprocess_input(question, schema):
    normalized_question = normalize_text(question)
    tokenized_question = tokenize_text(normalized_question)
    schema_links = link_question_to_schema(normalized_question, schema)
    return normalized_question, schema_links

# Generate SQL Query from the model
def generate_sql_query(model, tokenizer, question, schema, device):
    normalized_question, schema_links = preprocess_input(question, schema)
    input_ids, attention_mask = prepare_model_input(normalized_question, tokenizer, schema_links, device)
    model.eval()
    with torch.no_grad():
        outputs = model(input_ids, attention_mask)
        predictions = outputs.argmax(dim=2)
    decoded_query = tokenizer.decode(predictions[0], skip_special_tokens=True)
    return decoded_query

# Example usage
question = "What are the names and prices of all products in the electronics category?"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
sql_query = generate_sql_query(model, tokenizer, question, schema, device)
print("Generated SQL Query:", sql_query)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-4b62628976b1> in <cell line: 35>()
#      33 question = "What are the names and prices of all products in the electronics category?"
#      34 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# ---> 35 sql_query = generate_sql_query(model, tokenizer, question, schema, device)
#      36 print("Generated SQL Query:", sql_query)
#
# <ipython-input-30-4b62628976b1> in generate_sql_query(model, tokenizer, question, schema, device)
#      21 # Generate SQL Query from the model
#      22 def generate_sql_query(model, tokenizer, question, schema, device):
# ---> 23     normalized_question, schema_links = preprocess_input(question, schema)
#      24     input_ids, attention_mask = prepare_model_input(normalized_question, tokenizer, schema_links, device)
#      25     model.eval()
#
# <ipython-input-30-4b62628976b1> in preprocess_input(question, schema)
#      16     normalized_question = normalize_text(question)
#      17     tokenized_question = tokenize_text(normalized_question)
# ---> 18     schema_links = link_question_to_schema(normalized_question, schema)
#      19     return normalized_question, schema_links
#      20
#
# <ipython-input-29-a7ff8749abcd> in link_question_to_schema(question, tables)
#      42         best_match = None
#      43         highest_score = 0
# ---> 44         for table_name, info in tables.items():
#      45             table_score = fuzz.partial_ratio(token.lower(), table_name.lower())
#      46             if table_score > highest_score:
#
# AttributeError: 'list' object has no attribute 'items'

# %%
import re
import torch
from transformers import BertTokenizer
from nltk.tokenize import word_tokenize
from fuzzywuzzy import fuzz
import nltk
nltk.download('punkt')

# Define the schema
schema = {
    'table_names': ['products', 'categories'],
    'column_names': [
        (0, 'product_id'), (0, 'name'), (0, 'price'), (0, 'category_id'),
        (1, 'category_id'), (1, 'category_name')
    ]
}

# Preprocess functions
def normalize_text(text):
    """ Normalize text by lowering case and removing unwanted characters """
    text = text.lower()
    text = re.sub(r'[^a-zA-Z0-9\s,.*=<>()]', '', text)
    return text

def tokenize_text(text):
    """ Tokenize text using nltk's word_tokenize """
    return word_tokenize(text)

# def parse_schema(schema):
#     """ Parse the database schema into a dictionary mapping table names to their columns """
#     tables = {}
#     for table_idx, table_name in enumerate(schema['table_names']):
#         # Make sure to extract only the column name as a string, not a tuple
#         columns = [schema['column_names'][idx][1] for idx in range(len(schema['column_names'])) if schema['column_names'][idx][0] == table_idx]
#         tables[table_name] = columns
#     return tables

def parse_schema(schema):
    """ Parse the database schema into a dictionary mapping table names to their columns """
    tables = {}
    for table_idx, table_name in enumerate(schema['table_names']):
        # Extract only the column name as a string, not a tuple
        columns = [schema['column_names'][idx][1] for idx in range(len(schema['column_names'])) if schema['column_names'][idx][0] == table_idx]
        tables[table_name] = columns
    return tables

def link_question_to_schema(question, tables):
    """ Link tokens from the question to schema elements using fuzzy matching """
    linked_elements = {}
    tokens = tokenize_text(question)
    for token in tokens:
        best_match = None
        highest_score = 0
        for table_name, columns in tables.items():
            # Check table name match
            table_score = fuzz.partial_ratio(token.lower(), table_name.lower())
            if table_score > highest_score:
                best_match = ('table', table_name)
                highest_score = table_score
            # Check column name match, ensuring column is a string
            for column in columns:
                # print(f"Comparing token {token} with column {column} (type: {type(column)})")
                column = column[1]
                # print(f"Comparing token {token} with column {column} (type: {type(column)})")
                column_score = fuzz.partial_ratio(token.lower(), column.lower())  # column must be a string
                if column_score > highest_score:
                    best_match = ('column', column)
                    highest_score = column_score
        if highest_score > 80:  # Adjust the threshold as needed
            linked_elements[token] = best_match
    return linked_elements

def generate_sql_query(model, tokenizer, question, schema, device):
    model.eval()

    # Normalize and preprocess the question
    normalized_question, schema_links = preprocess_input(question, schema)
    input_ids, attention_mask = prepare_model_input(normalized_question, tokenizer, schema_links, device)

    # Initialize target tokens with the start token
    start_token_id = tokenizer.cls_token_id
    tgt_tokens = torch.full((input_ids.size(0), 1), start_token_id, dtype=torch.long, device=device)

    # Match tgt_tokens length to input_ids length
    if tgt_tokens.size(1) < input_ids.size(1):
        padding = torch.full((input_ids.size(0), input_ids.size(1) - tgt_tokens.size(1)), tokenizer.pad_token_id, dtype=torch.long, device=device)
        tgt_tokens = torch.cat([tgt_tokens, padding], dim=1)

    print("Input IDs shape:", input_ids.shape)
    print("Target Tokens shape:", tgt_tokens.shape)
    print("Attention Mask shape:", attention_mask.shape)

    outputs = model(input_ids, attention_mask, tgt_tokens)  # Pass tgt_tokens matching the length of input_ids
    predictions = torch.argmax(outputs[:, -1, :], dim=-1)  # Getting the last token predictions
    decoded_query = tokenizer.decode(predictions, skip_special_tokens=True)
    return decoded_query

def beam_search(model, tokenizer, question, schema, device, beam_width=3):
    model.eval()
    # Initial setup
    input_ids, attention_mask = prepare_model_input(question, tokenizer, schema, device)
    start_token_id = tokenizer.cls_token_id
    sequences = [[start_token_id]]

    # Beam search
    for _ in range(50):  # Max sequence length
        all_candidates = []
        for seq in sequences:
            tgt_tokens = torch.tensor([seq], dtype=torch.long, device=device)
            with torch.no_grad():
                outputs = model(input_ids, attention_mask, tgt_tokens)
                next_token_logits = outputs[:, -1, :]
                probabilities = torch.softmax(next_token_logits, dim=-1)
            top_k_probs, top_k_tokens = torch.topk(probabilities, beam_width, dim=-1)

            # Expand each current candidate
            for i in range(beam_width):
                next_seq = seq + [top_k_tokens[0][i].item()]
                next_prob = top_k_probs[0][i].item()
                candidate = (next_seq, next_prob)
                all_candidates.append(candidate)

        # Order all candidates by probability
        ordered = sorted(all_candidates, key=lambda tup: tup[1], reverse=True)
        sequences = [x[0] for x in ordered[:beam_width]]  # Narrow down to the best beam_width sequences

    print("Input IDs shape:", input_ids.shape)
    print("Target Tokens shape:", tgt_tokens.shape)
    print("Attention Mask shape:", attention_mask.shape)

    # Decode the best sequence
    best_seq = sequences[0]
    decoded_query = tokenizer.decode(best_seq, skip_special_tokens=True)
    return decoded_query


def prepare_model_input(question, tokenizer, schema_links, device):
    """ Prepare model input combining question and schema information """
    schema_info = ' '.join([f"{k}:{v}" for k, v in schema_links.items()])
    combined_input = f"{question} [SEP] {schema_info}"
    inputs = tokenizer.encode_plus(
        combined_input,
        None,
        add_special_tokens=True,
        max_length=512,
        padding='max_length',
        return_attention_mask=True,
        truncation=True
    )
    input_ids = torch.tensor(inputs['input_ids']).unsqueeze(0).to(device)
    attention_mask = torch.tensor(inputs['attention_mask']).unsqueeze(0).to(device)
    return input_ids, attention_mask
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
question = "What are the names and prices of all products in the electronics category?"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = TextToSQLModel(tokenizer.vocab_size).to(device)  # Assume this is properly loaded

sql_query = beam_search(model, tokenizer, question, schema, device)

print("Generated SQL Query:", sql_query)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-76-cbaabd2e260e> in <cell line: 6>()
#       4 model = TextToSQLModel(tokenizer.vocab_size).to(device)  # Assume this is properly loaded
#       5
# ----> 6 sql_query = beam_search(model, tokenizer, question, schema, device)
#       7
#       8 print("Generated SQL Query:", sql_query)
#
# <ipython-input-75-153cac546c1d> in beam_search(model, tokenizer, question, schema, device, beam_width)
#     110             tgt_tokens = torch.tensor([seq], dtype=torch.long, device=device)
#     111             with torch.no_grad():
# --> 112                 outputs = model(input_ids, attention_mask, tgt_tokens)
#     113                 next_token_logits = outputs[:, -1, :]
#     114                 probabilities = torch.softmax(next_token_logits, dim=-1)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# <ipython-input-14-c5e92e95cf88> in forward(self, input_ids, attention_mask, tgt_tokens)
#      12         encoder_hidden_states = self.encoder(input_ids=input_ids, attention_mask=attention_mask)[0]
#      13         tgt_embeddings = self.embedding(tgt_tokens)  # Embedding target tokens
# ---> 14         decoder_outputs = self.decoder(tgt_embeddings, encoder_hidden_states)
#      15         output = self.output_linear(decoder_outputs)
#      16         return output
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py in forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, tgt_is_causal, memory_is_causal)
#     463
#     464         for mod in self.layers:
# --> 465             output = mod(output, memory, tgt_mask=tgt_mask,
#     466                          memory_mask=memory_mask,
#     467                          tgt_key_padding_mask=tgt_key_padding_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py in forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, tgt_is_causal, memory_is_causal)
#     854         else:
#     855             x = self.norm1(x + self._sa_block(x, tgt_mask, tgt_key_padding_mask, tgt_is_causal))
# --> 856             x = self.norm2(x + self._mha_block(x, memory, memory_mask, memory_key_padding_mask, memory_is_causal))
#     857             x = self.norm3(x + self._ff_block(x))
#     858
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py in _mha_block(self, x, mem, attn_mask, key_padding_mask, is_causal)
#     872     def _mha_block(self, x: Tensor, mem: Tensor,
#     873                    attn_mask: Optional[Tensor], key_padding_mask: Optional[Tensor], is_causal: bool = False) -> Tensor:
# --> 874         x = self.multihead_attn(x, mem, mem,
#     875                                 attn_mask=attn_mask,
#     876                                 key_padding_mask=key_padding_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/activation.py in forward(self, query, key, value, key_padding_mask, need_weights, attn_mask, average_attn_weights, is_causal)
#    1239                 is_causal=is_causal)
#    1240         else:
# -> 1241             attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1242                 query, key, value, self.embed_dim, self.num_heads,
#    1243                 self.in_proj_weight, self.in_proj_bias,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v, average_attn_weights, is_causal)
#    5380     q = q.view(tgt_len, bsz * num_heads, head_dim).transpose(0, 1)
#    5381     if static_k is None:
# -> 5382         k = k.view(k.shape[0], bsz * num_heads, head_dim).transpose(0, 1)
#    5383     else:
#    5384         # TODO finish disentangling control flow so we don't do in-projections when statics are passed
#
# RuntimeError: shape '[1, 8, 96]' is invalid for input of size 393216

# %%
sql_query
# Out:
# '[unused519]'

# %%
question = "What are the names of all products in the electronics category?"
sql_query = generate_sql_query(model, tokenizer, question, schema, device)
print("Generated SQL Query:", sql_query)
# Out:
# Input IDs shape: torch.Size([1, 512])
# Target Tokens shape: torch.Size([1, 512])
# Attention Mask shape: torch.Size([1, 512])
# Generated SQL Query: reassigned
